# %%
from Rotary_test import calc_rotary_R_mat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
r = calc_rotary_R_mat(d_head=4096 // 32, max_seq_len=60, max_rel_dist=50)

# %%
r.shape
# Out:
# torch.Size([10, 128, 128])

# %%
for i in range(0, 50, 5):
    sns.heatmap(r[i][:30, :30], vmin=-1, vmax=1)
    plt.title(i)
    plt.show()
